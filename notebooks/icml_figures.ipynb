# %% [markdown]
# # ICML Figures (Temporal Invariance)
#
# This notebook runs the figure pipeline using the codebase modules.

# %%
import os
import sys
from getpass import getpass

# --- 1. Clone from GitHub ---
if not os.path.exists("/content/temporal_invariance"):
    print(">>> Please enter your GitHub details to clone the private repo.")
    user = input("GitHub Username: ")
    token = getpass("GitHub Token (or Password): ")
    repo = "temporal_invariance" # Repo name
    
    print(f">>> Cloning {user}/{repo}...")
    # !git clone https://{user}:{token}@github.com/{user}/{repo}.git /content/temporal_invariance

# --- 2. Setup & Run ---
project_root = "/content/temporal_invariance"
os.chdir(project_root)
sys.path.append(os.path.join(project_root, "src"))

print(">>> Installing dependencies...")
# !pip install -q -r requirements.txt
# !pip install -q -e .

print(">>> Running pipeline...")
from ti.scripts.run_figures import run_from_config
run_from_config("configs/paper.yaml")
# Out:
# >>> Please enter your GitHub details to clone the private repo.
# >>> Cloning jinschofield/temporal_invariance...
# Cloning into '/content/temporal_invariance'...
# warning: You appear to have cloned an empty repository.
# >>> Installing dependencies...
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# ERROR: file:///content/temporal_invariance does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
# >>> Running pipeline...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1082797503.py in <cell line: 0>()
#      23
#      24 print(">>> Running pipeline...")
# ---> 25 from ti.scripts.run_figures import run_from_config
#      26 run_from_config("configs/paper.yaml")
#
# ModuleNotFoundError: No module named 'ti'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
