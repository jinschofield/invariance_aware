# %% [markdown]
# # Periodicity Study (Colab)
#
# This notebook clones the repo, installs dependencies, and runs the study on GPU.

# %%
import os
from pathlib import Path

REPO_URL = "https://github.com/jinschofield/invariance_aware.git"
REPO_DIR = Path("/content/invariance_aware")

if not REPO_DIR.exists():
    # !git clone {REPO_URL} {REPO_DIR}
else:
    # !git -C {REPO_DIR} pull

# %cd /content/invariance_aware

# !pip install -r requirements.txt
# !pip install -e .

import torch
print("CUDA available:", torch.cuda.is_available())

FAST = False  # set True for a quick run
FORCE_RETRAIN = False  # set True to retrain CRTR from scratch

cmd = "python -m periodicity_study.run_study --device cuda:0"
if FAST:
    cmd += " --fast"
if FORCE_RETRAIN:
    cmd += " --force-retrain"

# !{cmd}
